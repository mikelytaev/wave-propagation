# %%
import os
os.chdir('../../')
from rwp.kediffraction import *
from rwp.antennas import *
from rwp.environment import *
from rwp.WPVis import *

# %% [markdown]
# Preparing environment

# %%
env = Troposphere(flat=True)
env.z_max = 150
env.knife_edges = [KnifeEdge(range=500, height=50)]
antenna = Source(wavelength=1, height_m=50)

# %% [markdown]
# Starting calculation

# %%
kdc = KnifeEdgeDiffractionCalculator(src=antenna, env=env, max_range_m=1000)
field = kdc.calculate()
# Out:
# /home/mikhail/PycharmProjects/wave-propagation/propagators/ts.py:155: RuntimeWarning: divide by zero encountered in true_divide
#   f = 1j / p * (np.exp(-1j * p * b) - np.exp(-1j * p * a))
# /home/mikhail/PycharmProjects/wave-propagation/propagators/ts.py:155: RuntimeWarning: invalid value encountered in true_divide
#   f = 1j / p * (np.exp(-1j * p * b) - np.exp(-1j * p * a))
# /home/mikhail/PycharmProjects/wave-propagation/propagators/ts.py:155: RuntimeWarning: invalid value encountered in multiply
#   f = 1j / p * (np.exp(-1j * p * b) - np.exp(-1j * p * a))
# /home/mikhail/PycharmProjects/wave-propagation/venv3.7/lib/python3.7/site-packages/scipy/sparse/linalg/dsolve/linsolve.py:133: SparseEfficiencyWarning: spsolve requires A be CSC or CSR matrix format
#   SparseEfficiencyWarning)

# %% [markdown]
# Visualising results

# %%
vis = FieldVisualiser(field, trans_func=lambda v: 10 * cm.log10(1e-16 + abs(v)), label='ke')
plt = vis.plot2d(min=-40, max=0)
plt.title('The intensity of the field component 10log10|u|')
plt.xlabel('Range (m)')
plt.ylabel('Height (m)')
plt.show()

plt = vis.plot_hor(50)
plt.title('The intensity of the field component 10log10|u| at the height 50 m')
plt.xlabel('Range (m)')
plt.ylabel('10log|u| (dB)')
plt.show()
